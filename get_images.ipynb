# %%
from google_images_download import google_images_download
import numpy as np
from PIL import Image
import os

# %%
response = google_images_download.googleimagesdownload()
arguments = {"keywords":"galaxy","limit":100,"print_urls":True}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = galaxy
# Evaluating...
# Starting Download...
# Image URL: https://upload.wikimedia.org/wikipedia/commons/c/c3/NGC_4414_%28NASA-med%29.jpg
# Completed Image ====> 1.NGC_4414_%28NASA-med%29.jpg
# Image URL: https://wp-assets.futurism.com/2019/01/hubble-image-triangulum-galaxy-1200x630.jpg
# Completed Image ====> 2.hubble-image-triangulum-galaxy-1200x630.jpg
# Image URL: https://img.purch.com/h/1000/aHR0cDovL3d3dy5saXZlc2NpZW5jZS5jb20vaW1hZ2VzL2kvMDAwLzEwMi8wOTYvb3JpZ2luYWwvc2h1dHRlcnN0b2NrXzY4NzM2NTg3Mi5qcGc=
# Invalid or missing image format. Skipping...
# Image URL: https://upload.wikimedia.org/wikipedia/commons/5/52/Hubble2005-01-barred-spiral-galaxy-NGC1300.jpg
# Completed Image ====> 3.Hubble2005-01-barred-spiral-galaxy-NGC1300.jpg
# Image URL: https://images.theconversation.com/files/223749/original/file-20180619-126537-5l632j.jpg?ixlib=rb-1.1.0&q=45&auto=format&w=496&fit=clip
# Completed Image ====> 4.file-20180619-126537-5l632j.jpg
# ...

# %%
image_directory = "spiral-galaxy"
offset = 0
limit = 3000
response = google_images_download.googleimagesdownload()
arguments = {"keywords":"spiral galaxy","limit":limit,"print_urls":False, "offset":offset, "image_directory":image_directory, "chromedriver":"/usr/local/bin/chromedriver"}
path = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = spiral galaxy
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1.wWieWanunf3ct2xtaEVAwY-320-80.jpg
# Completed Image ====> 2.1280px-M101_hires_STScI-PRC2006-10a.jpg
# Completed Image ====> 3.opo9925a.jpg
# Completed Image ====> 4.NGC1672_Hubble_3600.jpg
# Completed Image ====> 5.eso9845d.jpg
# Completed Image ====> 6.Ssc2003-06c.jpg
# Completed Image ====> 7.SpiralGalaxy1_copy_1024x1024.jpg
# Completed Image ====> 8.iStock-613869830.jpg
# Completed Image ====> 9.image_5232e-NGC-6753.jpg
# Completed Image ====> 10.milky_way_300.jpg
# Completed Image ====> 11.Whirlpool_1024px-An_Oasis_or_a_Secret_Lair-1-59c5d24068e1a20014de2afa.jpg
# Completed Image ====> 12.Hubble-Views-Intermediate-Spiral-Galaxy-NGC-1566.jpg
# Completed Image ====> 13.M31_Spiral_Galaxy.jpg
# Completed Image ====> 14.1*dImb8e-eb8KA6NS67lMNWQ.jpeg
# ...

# %%
image_directory = "spiral-galaxy"
offset = 1000
limit = 500
response = google_images_download.googleimagesdownload()
arguments = {"keywords":"spiral galaxy","limit":limit,"print_urls":False, "offset":offset, "image_directory":image_directory, "chromedriver":"/usr/local/bin/chromedriver"}
path = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = spiral galaxy
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
#
#
# Unfortunately all 500 could not be downloaded because some images were not downloadable. 398 is all we got for this search filter!
#
# Errors: 0
